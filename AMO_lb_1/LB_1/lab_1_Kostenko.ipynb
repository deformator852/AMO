# %%
from IPython.display import Image
Image('images/zxc.jpg')

# %%
#Скрiн першого пункту не робив
# Out:
# 1.) Скрiн першого пункту не робив

# %%
#Cкрiн 2 пункту ЛБ
Image('images/2.png')
# Out:
# 2.) Cкрiн 2 пункту ЛБ

# %%
#Cкрiн 3 пункту ЛБ
Image('images/3.png')
# Out:
# 3.) Cкрiн 3 пункту ЛБ

# %%
#контрольні запитання
#1.)pip -  це програма для встановлення бібліотек, пакетів для python.
#conda - це теж саме.
#вiдмiни - рiзнi репозиторії,pip бiльш простiше,сonda може може керувати віртуальними оточеннями.
#2.)pip install virtualenv
#virtualenv Kostenko_OpenCV
#source Kostenko_OpenCV/bin/activate (це пiд лiнукс)
#pip install opencv-python
#3.)майже моє фото
#4.)
arr = [12,0,66,8,9,5,67,13]

swap = False
while swap !=True:
    swap = True
    for i in range(len(arr)-1):
        if arr[i]>arr[i+1]:
            tmp = arr[i]
            arr[i] = arr[i+1]
            arr[i+1] = tmp
            swap=False
print(arr)
#5.)можна використовувати функцію nbconvert прямо з кодової клітинки Jupyter
# Out:
# [0, 5, 8, 9, 12, 13, 66, 67]
